# %% [markdown]
# <a href="https://colab.research.google.com/github/FadyMamdouh01/alx-low_level_programming/blob/master/CompVisionLap04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4]) 
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
t = np.arange(0,2.5,0.1)
y1 = np.sin(np.pi*t)
y2 = np.sin(np.pi*t+np.pi/2)
y3 = np.sin(np.pi*t-np.pi/2)
plt.plot(t,y1,'r*',t,y2,'g^',t,y3,'ys')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.xlabel('Counting')
plt.ylabel('Square values')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.grid()

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.xlabel('Counting')
plt.ylabel('Square values')
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
plt.legend(['First series','Second series','Third series'],loc=8)
plt.savefig("my chart.png")

# %%
pop = np.random.randint(0, 100, 100)
n, bins, patches = plt.hist(pop, bins=20)

# %%
index = [0,11,2,3,4]
values = [5,7,3,7,6]
plt.bar(index,values)
# Out:
# <BarContainer object of 5 artists>

# %%
index = [0,1,22,3,4]
values = [5,7,3,12,6]
plt.barh(index,values)
# Out:
# <BarContainer object of 5 artists>

# %%
labels = ['Nokia','Samsung','Apple','Lumia']
values = [23,27,50,10]
colors = ['black','darkblue','yellow','blue']
plt.pie(values,labels=labels,colors=colors)
plt.axis('equal')
# Out:
# (-1.1286112881345916,
#  1.1013624516456448,
#  -1.1302757416358689,
#  1.1363160276736808)

# %%
dx = 0.01;
dy = 0.01
x = np.arange(-2.0,2.0,dx)
y = np.arange(-2.0,2.0,dy)
X,Y = np.meshgrid(x,y)
def f(x,y):
    return (1 - y**5 + x**5)*np.exp(-x**2 - y**2)
C = plt.contour(X,Y,f(X,Y),8,colors='red')
plt.contourf(X,Y,f(X,Y),8)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X = np.arange(-2, 2, 0.1)
Y = np.arange(-2, 2, 0.1)
X, Y = np.meshgrid(X, Y)

def f(x, y):
    return (1 - y**5 + x**5) * np.exp(-x**2 - y**2)

ax.plot_surface(X, Y, f(X, Y), rstride=1, cstride=1)

plt.show()

# %%
xs = np.random.randint(30,40,100)
ys = np.random.randint(20,30,100)
zs = np.random.randint(10,20,100)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(xs,ys,zs)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# Out:
# C:\Users\fadym\AppData\Local\Temp\ipykernel_4848\4279757370.py:5: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Text(0.5, 0, 'Z Label')
